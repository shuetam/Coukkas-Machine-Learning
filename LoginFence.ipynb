# %% [markdown]
# # Login

# %%
import requests

url = "http://www.coukkas.com.pl/account/login"

payload = "{\"Password\": \"haslo\", \"Email\": \"mat@coukkas.api\" }\n"
headers = {
    'Content-Type': "application/json",
    'Cache-Control': "no-cache"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.status_code)
print(response.text)
token = response.json()["token"]
print(token)
# Out:
# 200
# {
#   "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....HYY7iUOy1ChBKn_SYySAwwxCRzteT4jCOTKbPsnIqzg",
#   "expire": "2018-03-17T10:23:16.1487589Z",
#   "role": "User"
# }
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....HYY7iUOy1ChBKn_SYySAwwxCRzteT4jCOTKbPsnIqzg

# %% [markdown]
# # Create fence

# %%
import requests

url = "http://www.coukkas.com.pl/fence/create"

payload = "{\"Name\": \"Nike\", \"Description\": \"Voucher 30zl\", \"Category\": \"sport\", \"Days\": 7000, \"Radius\": 13000, \"lat\": 50.0846501, \"lon\": 19.6449799}\n\n"
headers = {
    'Content-Type': "application/json",
    'Authorization': 'Bearer 
    'Cache-Control': "no-cache"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.status_code)
# Out:
#   File "<ipython-input-2-9fe96d5ff041>", line 8
#     'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....HYY7iUOy1ChBKn_SYySAwwxCRzteT4jCOTKbPsnIqzg
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Show all fences data

# %%
import requests
response = requests.get(url='http://www.coukkas.com.pl/fence/alldatafences')
allfencesdata = response.json()
print(response.text)
# Out:
# [
#   {
#     "name": "Nike",
#     "category": "sport",
#     "radius": 13000.0,
#     "latitude": 50.0846501,
#     "longitude": 19.6449799
#   }
# ]

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text




map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="roadmap", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"



category_colors = {'undefined': 'black', 
                    'cinema': 'blue', 
                    'travel': 'yellow', 
                    'parties': 'pink', 
                    'sport': 'red', 
                    'garden': 'green',
                    'groceries': 'orange'}



fnames = [l['name'] for l in allfencesdata]
colors = [category_colors[l['category']] for l in allfencesdata]
radiuses = [float(l['radius']) for l in allfencesdata]
latitudes = [float(l['latitude']) for l in allfencesdata]
longitudes = [float(l['longitude']) for l in allfencesdata]
        


source_for_map = ColumnDataSource(
    data=dict(
        names = fnames,
        rad = radiuses,
        lat = latitudes,
        lon = longitudes,
        col = colors
    )
)


circles = Circle(x="lon", y="lat", radius="rad", fill_color='col', fill_alpha=0.5, line_color="blue")
labels = LabelSet(x="lon", y="lat", text='names', level='glyph',
              x_offset=0, y_offset=0, source=source_for_map, render_mode='canvas')

plot.add_glyph(source_for_map, circles)
plot.add_layout(labels)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5cdc1135-061b-41c3-9c36-5b6501ae3549">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6dd1cae3-462e-4234-aa17-ef5f3aaef614"></div>
# </div>
