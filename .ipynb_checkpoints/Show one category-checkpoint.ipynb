# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text
import requests

#POBRANIE DANYCH W FORMACIE JSON:
response = requests.get(url="http://www.coukkas.com.pl/account/factsdata_year=2017_days=9-16")
all_facts_data_1 = response.json()
all_facts_data = [x for x in all_facts_data_1 if x['category'] == 'sport']

#USTALENIE PAREMETRÓW DLA MAPY GOOGLE:
map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="roadmap", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"

#NADANIE KOLORÓW DLA KATEGORII:
category_colors = {
                    'art': 'black', 
                    'cinema': 'blue', 
                    'travel': 'yellow', 
                    'parties': 'pink', 
                    'sport': 'red', 
                    'garden': 'green',
                    'groceries': 'orange',
                    'toys': '#B57EDC',
                    'clothes': '#89CFF0',
                    'shoes':'#483C32',
                    'electronic':'#00FF3F',
                    'motorization': 'grey',
                    'cosmetics': 'purple',
                    'home': 'brown',
                    'office': 'olive',
                    'construction': '#808080',
                    'shool': 'navy',
                    'babies': 'rose',
                    'concerts': '#BFFF00',
                    'theatre': 'peach',
                    'books': '#7F00FF',
                    'health': '#0095B6',
                    'pets': '#B87333',
                    'restaurants': '#A7FC00'
                    }


colors = [category_colors[l['category']] for l in all_facts_data]
latitudes = [float(l['location']['latitude']) for l in all_facts_data]
longitudes = [float(l['location']['longitude']) for l in all_facts_data]
 
#DANE GEOGRAFICZNE I KOLORY DLA MAPY GOOGLE:
source_for_map = ColumnDataSource(
    data=dict(
        lat = latitudes,
        lon = longitudes,
        col = colors
    )
)

#ZADEFINIOWANIE PARAMETRÓW DLA PUNKTÓW:
circles = Circle(x="lon", y="lat", size=5, fill_color='col', line_color="col", fill_alpha=0.6,line_alpha=0.0)

#WYDRUK WIZUALIZACJI:
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
plot.add_glyph(source_for_map, circles)



# centroidy:

lat_c = [50.04176578994768, 50.01811657603657, 50.081421348453304, 50.08046773855327, 50.0250275875282, 50.07258911119625, 50.02657228335077, 50.05664611393903]
lon_c = [20.019230600763983, 19.870596632756083, 20.099584489776692, 19.976481296784215, 20.09632885796053, 19.898409225453104, 19.943689412247952, 19.83746853840367]


source_for_map_c = ColumnDataSource(
    data=dict(
        latc = lat_c,
        lonc = lon_c,
    )
)

centroids = Circle(x="lonc", y="latc", size=7, fill_color='blue', line_color="black", fill_alpha=0.6,line_alpha=0.0)

plot.add_glyph(source_for_map_c, centroids)

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b834b117-403a-479d-80a4-f90f8ed5811d">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="cb40cdf7-2a14-4600-915f-576eb0eb6e0c"></div>
# </div>

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text
import requests

#POBRANIE DANYCH W FORMACIE JSON:
response = requests.get(url="http://www.coukkas.com.pl/account/factsdata_year=2017_days=200-202")
all_facts_data = response.json()

#USTALENIE PAREMETRÓW DLA MAPY GOOGLE:
map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="roadmap", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"

#NADANIE KOLORÓW DLA KATEGORII:
category_colors = {
                    'art': 'black', 
                    'cinema': 'blue', 
                    'travel': 'yellow', 
                    'parties': 'pink', 
                    'sport': 'red', 
                    'garden': 'green',
                    'groceries': 'orange',
                    'toys': '#B57EDC',
                    'clothes': '#89CFF0',
                    'shoes':'#483C32',
                    'electronic':'#00FF3F',
                    'motorization': 'grey',
                    'cosmetics': 'purple',
                    'home': 'brown',
                    'office': 'olive',
                    'construction': '#808080',
                    'shool': 'navy',
                    'babies': 'rose',
                    'concerts': '#BFFF00',
                    'theatre': 'peach',
                    'books': '#7F00FF',
                    'health': '#0095B6',
                    'pets': '#B87333',
                    'restaurants': '#A7FC00'
                    }


colors = [category_colors[l['category']] for l in all_facts_data]
latitudes = [float(l['location']['latitude']) for l in all_facts_data]
longitudes = [float(l['location']['longitude']) for l in all_facts_data]
 
#DANE GEOGRAFICZNE I KOLORY DLA MAPY GOOGLE:
source_for_map = ColumnDataSource(
    data=dict(
        lat = latitudes,
        lon = longitudes,
        col = colors
    )
)

#ZADEFINIOWANIE PARAMETRÓW DLA PUNKTÓW:
circles = Circle(x="lon", y="lat", size=5, fill_color='col', line_color="col", fill_alpha=0.6,line_alpha=0.0)

#WYDRUK WIZUALIZACJI:
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
plot.add_glyph(source_for_map, circles)
show(plot)
