# %%
import requests
response = requests.get(url='http://www.coukkas.com.pl/values/regions')
alldata = response.text
print(alldata)
# Out:
# [
#   {
#     "latitude": 50.0,
#     "longitude": 50.0,
#     "id": 13
#   },
#   {
#     "latitude": 51.0,
#     "longitude": 52.0,
#     "id": 14
#   },
#   {
#     "latitude": 52.0,
#     "longitude": 51.0,
#     "id": 15
#   },
#   {
#     "latitude": 52.0,
#     "longitude": 53.0,
#     "id": 16
#   },
#   {
#     "latitude": 70.0,
#     "longitude": 20.0,
#     "id": 17
#   },
#   {
#     "latitude": 52.0,
#     "longitude": 34.0,
#     "id": 18
#   },
#   {
#     "latitude": 5.0,
#     "longitude": 34.0,
#     "id": 19
#   },
#   {
#     "latitude": 59.0,
#     "longitude": 50.0,
#     "id": 20
#   },
#   {
#     "latitude": 50.061509,
#     "longitude": 19.944035,
#     "id": 21
#   }
# ]

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text
map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="roadmap", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"
latitudes = [float(l['latitude']) for l in alldata]
longitudes = [float(l['longitude']) for l in alldata]

source_for_map = ColumnDataSource(
    data=dict(
        lat = latitudes,
        lon = longitudes,
    )
)
circles = Circle(x="lon", y="lat", radius=10000, fill_color='red', fill_alpha=0.5, line_color="red")

plot.add_glyph(source_for_map, circles)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ef190f85-1cc1-4f81-a5a6-5163aa13de04">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e3e5c8d9cba8> in <module>()
#       9 plot.title.text = "Kraków"
#      10 plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"
# ---> 11 latitudes = [float(l['latitude']) for l in alldata]
#      12 longitudes = [float(l['longitude']) for l in alldata]
#      13
#
# NameError: name 'alldata' is not defined

# %%
import requests

url = "http://localhost:5000/account/login"

payload = "{\"Password\": \"haslo\", \"Email\": \"mat@coukkas.api\" }\n\n\n"
headers = {
    'Content-Type': "application/json",
    'Cache-Control': "no-cache",
    'Postman-Token': "388c222f-4fd3-47de-b32e-d296420aca05"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.json()['token'])
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....IwR5_K6cRglfbgCfTV0J8eyoQepzAeuWDs8DTnBjQ3k

# %%
import requests

url = "http://localhost:5000/fence/create"

payload = "{\"Name\": \"Lidl333\", \"Description\": \"Voucher 50zl\", \"Category\": \"groceries\", \"Days\": 7000, \"Radius\": 12000, \"lat\": 50.061509, \"lon\": 19.944035}"
headers = {
    'Content-Type': "application/json",
    'Authorization': "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....IwR5_K6cRglfbgCfTV0J8eyoQepzAeuWDs8DTnBjQ3k",
    'Cache-Control': "no-cache",
    'Postman-Token': "39495f57-8904-4f89-9ab9-9562bbcea60c"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
