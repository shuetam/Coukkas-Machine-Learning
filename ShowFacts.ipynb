# %% [markdown]
# # Show Facts

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text
import requests

#POBRANIE DANYCH W FORMACIE JSON:
response = requests.get(url="http://www.coukkas.com.pl/account/factsdata_year=2017_days=9-11")
all_facts_data = response.json()

#USTALENIE PAREMETRÓW DLA MAPY GOOGLE:
map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="roadmap", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"

#NADANIE KOLORÓW DLA KATEGORII:
category_colors = {
                    'art': 'black', 
                    'cinema': 'blue', 
                    'travel': 'yellow', 
                    'parties': 'pink', 
                    'sport': 'red', 
                    'garden': 'green',
                    'groceries': 'orange',
                    'toys': '#B57EDC',
                    'clothes': '#89CFF0',
                    'shoes':'#483C32',
                    'electronic':'#00FF3F',
                    'motorization': 'grey',
                    'cosmetics': 'purple',
                    'home': 'brown',
                    'office': 'olive',
                    'construction': '#808080',
                    'shool': 'navy',
                    'babies': 'rose',
                    'concerts': '#BFFF00',
                    'theatre': 'peach',
                    'books': '#7F00FF',
                    'health': '#0095B6',
                    'pets': '#B87333',
                    'restaurants': '#A7FC00'
                    }


colors = [category_colors[l['category']] for l in all_facts_data]
latitudes = [float(l['location']['latitude']) for l in all_facts_data]
longitudes = [float(l['location']['longitude']) for l in all_facts_data]
 
#DANE GEOGRAFICZNE I KOLORY DLA MAPY GOOGLE:
source_for_map = ColumnDataSource(
    data=dict(
        lat = latitudes,
        lon = longitudes,
        col = colors
    )
)

#ZADEFINIOWANIE PARAMETRÓW DLA PUNKTÓW:
circles = Circle(x="lon", y="lat", size=2, fill_color='col', line_color="col", fill_alpha=0.6,line_alpha=0.0)

#WYDRUK WIZUALIZACJI:
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
plot.add_glyph(source_for_map, circles)
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2a3a24f3-1465-4f18-8a06-3777597f9da9">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     600                     break
# --> 601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _handle_chunk(self, amt)
# ...

# %% [markdown]
# # One category

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Label, LabelSet
)
from bokeh.models.glyphs import Text

import requests

year = 2017
from_day = 1
to_day = 2

response = requests.get(url="http://www.coukkas.com.pl/account/factsdata_year=2017_days=9-11")
all_facts_data = list( filter(lambda x: x['category'] == 'clothes', response.json())).json()  


map_options = GMapOptions(lat=50.0614300, lng=19.9365800, map_type="shool", zoom=11)
plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options, plot_height=800, plot_width=980)
plot.title.text = "Kraków"
plot.api_key = "AIzaSyC2s9N7qsU48BL83Zaj-OCE6pqpvtTsxtM"

category_colors = {
                    'art': 'black', 
                    'cinema': 'blue', 
                    'travel': 'yellow', 
                    'parties': 'pink', 
                    'sport': 'red', 
                    'garden': 'green',
                    'groceries': 'orange',
                    'toys': '#B57EDC',
                    'clothes': '#89CFF0',
                    'shoes':'#483C32',
                    'electronic':'#00FF3F',
                    'motorization': 'grey',
                    'cosmetics': 'purple',
                    'home': 'brown',
                    'office': 'olive',
                    'construction': '#808080',
                    'shool': 'navy',
                    'babies': 'rose',
                    'concerts': '#BFFF00',
                    'theatre': 'peach',
                    'books': '#7F00FF',
                    'health': '#0095B6',
                    'pets': '#B87333',
                    'restaurants': '#A7FC00'
                    }


colors = [category_colors[l['category']] for l in all_facts_data]
latitudes = [float(l['location']['latitude']) for l in all_facts_data]
longitudes = [float(l['location']['longitude']) for l in all_facts_data]
        
source_for_map = ColumnDataSource(
    data=dict(
        lat = latitudes,
        lon = longitudes,
        col = colors
    )
)

circles = Circle(x="lon", y="lat", size=4, fill_color='col', line_color="col", fill_alpha=0.9,line_alpha=0.0)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
plot.add_glyph(source_for_map, circles)
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="df16c8cf-fabb-49bc-9c27-9556b93ca5ae">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-fe7ef5a937ad> in <module>()
#      13
#      14 response = requests.get(url="http://www.coukkas.com.pl/account/factsdata_year=2017_days=9-11")
# ---> 15 all_facts_data = list( filter(lambda x: x['category'] == 'clothes', response.json())).json()
#      16
#      17
#
# AttributeError: 'list' object has no attribute 'json'
